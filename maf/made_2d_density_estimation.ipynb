# %%
# %reload_ext autoreload
# %autoreload 2

import time

import numpy as np
import torch
import torch.optim as optim
import matplotlib.pyplot as plt

from mades import MADE, MADE_MOG
from mafs import MAF, MAF_MOG

from torch.utils.data import TensorDataset, DataLoader

# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ## Data

# %%
potential_func_name = "U3"

# %%
data = torch.from_numpy(np.load(f"2d_data/{potential_func_name}_samples_10000.npy"))

# %%
plt.figure(figsize=(5, 5))
plt.scatter(data[:, 0], data[:, 1], s=0.01, color="black")
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## MADE

# %%
made = MADE(data_dim=2, hidden_dims=[100, 100])
opt = optim.Adam(made.parameters(), lr=1e-3)

start_time = time.perf_counter()

for i in range(1, 10001):

    loss = - made.log_prob(data).mean()
    opt.zero_grad()
    loss.backward()
    opt.step()

    if (i % 100) == 0:
        curr_time = time.perf_counter()
        print(i, float(loss), curr_time - start_time)
        start_time = time.perf_counter()
# Out:
# 100 5.435001373291016 1.2517024590000005
# 200 4.696734428405762 1.2190184160000115
# 300 4.256409168243408 1.220966875000002
# 400 3.992884874343872 1.2948755000000034
# 500 3.794900894165039 1.627302874999998
# 600 3.6429696083068848 1.4759254169999991
# 700 3.523860454559326 1.2426733749999954
# [E thread_pool.cpp:109] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:109] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:109] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:109] Exception in thread pool task: mutex lock failed: Invalid argument
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 6>()
#       4 start_time = time.perf_counter()
#       6 for i in range(1, 10001):
# ----> 8     loss = - made.log_prob(data).mean()
#       9     opt.zero_grad()
#      10     loss.backward()
#
# File ~/Desktop/projects/maf-pytorch/maf/mades.py:143, in MADE.log_prob(self, x)
#     142 def log_prob(self, x):
# --> 143     u, logabsdet = self.calc_u_and_logabsdet(x)
#     144     log_prob_under_u = self.base_dist.log_prob(u)
#     145     log_prob = log_prob_under_u + logabsdet
#
# File ~/Desktop/projects/maf-pytorch/maf/mades.py:136, in MADE.calc_u_and_logabsdet(self, x)
#     134 def calc_u_and_logabsdet(self, x):
#     135     """Only call this method directly when stacking GaussianMADEs into an MAF"""
# --> 136     mu, alpha = self.calc_mu_and_alpha(x)
#     137     alpha_clipped = torch.clip(alpha, -5, 5)  # std max: exp(5) = 148; std min: exp(-5) = 0.006
#     138     u = (x - mu) * torch.exp(-alpha_clipped)
#
# File ~/Desktop/projects/maf-pytorch/maf/mades.py:131, in MADE.calc_mu_and_alpha(self, x)
#     124 def calc_mu_and_alpha(self, x):
#     125     """
#     126     x: (bs, D)
#     127     h: (bs, H)
#     128     mu: (bs, D)
#     129     alpha: (bs, D)
#     130     """
# --> 131     h = self.hidden(x)
#     132     return self.mu(h), self.alpha(h)
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/modules/activation.py:517, in ELU.forward(self, input)
#     516 def forward(self, input: Tensor) -> Tensor:
# --> 517     return F.elu(input, self.alpha, self.inplace)
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/functional.py:1548, in elu(input, alpha, inplace)
#    1546     result = torch._C._nn.elu_(input, alpha)
#    1547 else:
# -> 1548     result = torch._C._nn.elu(input, alpha)
#    1549 return result
#
# KeyboardInterrupt:

# %%
xs = torch.linspace(-6, 6, 100)
ys = torch.linspace(-6, 6, 100)
xxs, yys = torch.meshgrid(xs, ys)
xxs_flat, yys_flat = xxs.reshape(-1, 1), yys.reshape(-1, 1)
grid = torch.hstack([xxs_flat, yys_flat])
# Out:
# /Users/zhihanyang/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
with torch.no_grad():
    probs = made.log_prob(grid).exp()

plt.figure(figsize=(5, 5))
plt.contourf(xxs.numpy(), yys.numpy(), probs.numpy().reshape(100, 100), levels=100, cmap="turbo")
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xticks([])
plt.yticks([])
#plt.savefig(f"./saved/made_2d_density_estimation/{potential_func_name}_gaussian_made.png", dpi=300, bbox_inches='tight')
# Out:
# ([], [])

# %% [markdown]
# ## Mixture of Gaussians MADE

# %%
made_mog = MADE_MOG(data_dim=2, hidden_dims=[100, 100], num_components=10)
opt = optim.Adam(made_mog.parameters(), lr=1e-3)

start_time = time.perf_counter()

for i in range(1, 10001):

    loss = -made_mog.log_prob(data).mean()
    opt.zero_grad()
    loss.backward()
    opt.step()

    if (i % 100) == 0:
        curr_time = time.perf_counter()
        print(i, float(loss), curr_time - start_time)
        start_time = time.perf_counter()
# Out:
# 100 5.151761531829834 1.853985499999908
# 200 4.634710788726807 1.8688440420000916
# 300 4.2382001876831055 1.8914288749999741
# 400 3.9518535137176514 1.8448235420000856
# 500 3.7436442375183105 1.8939674580001338
# 600 3.5842230319976807 1.873681999999917
# 700 3.4588987827301025 1.8811838330000228
# 800 3.360271453857422 1.8497971249998955
# 900 3.2831928730010986 1.9697912910000923
# 1000 3.2210090160369873 1.8730407919999834
# 1100 3.1711645126342773 1.8781319170000188
# 1200 3.1317062377929688 1.9113686250000228
# 1300 3.099362850189209 1.9180069579999781
# 1400 3.0738415718078613 1.8818951670000388
# 1500 3.0532939434051514 1.8893022919999112
# 1600 3.039109468460083 1.9352989159999652
# 1700 3.0235748291015625 1.886195042000054
# 1800 3.0136208534240723 1.8784529580000253
# 1900 3.0048375129699707 1.9337587080001413
# 2000 2.998246908187866 1.8981699159999152
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 6>()
#       4 start_time = time.perf_counter()
#       6 for i in range(1, 10001):
# ----> 8     loss = -made_mog.log_prob(data).mean()
#       9     opt.zero_grad()
#      10     loss.backward()
#
# File ~/Desktop/projects/maf-pytorch/maf/mades.py:246, in MADE_MOG.log_prob(self, x)
#     245 def log_prob(self, x):
# --> 246     mu, log_std, log_pi = self.calc_mu_and_log_std_and_log_pi(x)
#     247     return mog_1d_loglik_batch(x, mu, log_std, log_pi).sum(dim=1)
#
# File ~/Desktop/projects/maf-pytorch/maf/mades.py:232, in MADE_MOG.calc_mu_and_log_std_and_log_pi(self, x)
#     218 """
#     219 x: (bs, D)
#     220 h: (bs, H)
#    (...)
#     226 pi: (bs, D, C)
#     227 """
#     229 h = self.hidden(x)
#     231 mu = \
# --> 232     torch.einsum(self._formula, h, torch.transpose(self.mu_W * self.final_mask, 0, 1)) + self.mu_b
#     233 log_std = \
#     234     torch.einsum(self._formula, h, torch.transpose(self.log_std_W * self.final_mask, 0, 1)) + self.log_std_b
#     236 # logit_pi differs from log_pi in the sense that logit_pi is the log UNNORMALIZED probabilities
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/functional.py:378, in einsum(*args)
#     373     return einsum(equation, *_operands)
#     375 if len(operands) <= 2 or not opt_einsum.enabled:
#     376     # the path for contracting 0 or 1 time(s) is already optimized
#     377     # or the user has disabled using opt_einsum
# --> 378     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     380 path = None
#     381 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    probs = made_mog.log_prob(grid).exp()
    # means, log_stds, log_pis = mog_made.calc_mu_and_log_std_and_log_pi(torch.vstack([xs, ys]).T)
    # means = means[:, 1]

plt.figure(figsize=(5, 5))

plt.contourf(
    xxs.numpy(), yys.numpy(), probs.numpy().reshape(100, 100),
    levels=20, cmap="turbo", extent=[-5, 9, -7.5, 7.5]
)

plt.xticks([])
plt.yticks([])

#plt.savefig(f"./saved/made_2d_density_estimation/{potential_func_name}_mog_c10_made.png", dpi=300, bbox_inches='tight')
# Out:
# ([], [])

# %%
plt.figure(figsize=(5, 5))

with torch.no_grad():
    samples = mog_made.sample(10000).numpy()

plt.scatter(samples[:, 0], samples[:, 1], color="black", s=0.01)

plt.xlim(-6, 6)
plt.ylim(-6, 6)

plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ## MAF(5)

# %%
train_ds = TensorDataset(data[:8000])
train_dl = DataLoader(train_ds, batch_size=100)

# %%
maf = MAFOnGaussian(data_dim=2, hidden_dims=[100, 100], num_ar_layers=10)

# %%
maf = MAFOnGaussian(data_dim=2, hidden_dims=[100, 100], num_ar_layers=10, reverse_input_order=False)

# %%
maf = MADE_MOG(data_dim=2, hidden_dims=[100, 100], num_components=10)
opt = optim.Adam(maf.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(opt, milestones=[100, 200], gamma=1/3)

losses_epoch = []

for i in range(300):
    
    losses_batch = []

    for (xb, ) in train_dl:
    
        loss = - maf.log_prob(xb).mean()
        
        losses_batch.append(float(loss))
        
        opt.zero_grad()
        loss.backward()
        opt.step()

    losses_batch_mean = np.mean(losses_batch)
    print(i+1, losses_batch_mean)
    losses_epoch.append(losses_batch_mean)
    
    scheduler.step()
# Out:
# 1 6.031325161457062
# 2 5.290305739641189
# 3 4.71892478466034
# 4 4.401891380548477
# 5 4.150279513001442
# 6 3.9507094383239747
# 7 3.792197236418724
# 8 3.6636610209941862
# 9 3.5582844734191896
# 10 3.4710752189159395
# 11 3.399240916967392
# 12 3.3394817292690275
# 13 3.288901671767235
# 14 3.2463280737400053
# 15 3.2102779388427733
# 16 3.1794927567243576
# 17 3.1530943751335143
# 18 3.1306860566139223
# 19 3.111575257778168
# 20 3.0954649955034257
# 21 3.081902825832367
# 22 3.0703731209039686
# 261 2.9754805743694304
# 262 2.9754929661750795
# 263 2.975477561354637
# 264 2.975455975532532
# 265 2.9754594057798385
# 266 2.9754618376493456
# 267 2.9754591166973112
# 268 2.975440835952759
# 269 2.9754323035478594
# 270 2.9754330813884735
# 271 2.9754337817430496
# 272 2.9754249542951583
# 273 2.9754156082868577
# 274 2.9754128456115723
# 275 2.9754136949777603
# 276 2.9754082381725313
# 277 2.975398999452591
# 278 2.975395494699478
# 279 2.975396493077278
# 280 2.975393331050873
# 281 2.9753818571567536
# 282 2.975378519296646
# 283 2.9753820210695268
# 284 2.975382721424103
# 285 2.975366124510765
# 286 2.975358620285988
# 287 2.975360596179962
# 288 2.9753614872694016
# 289 2.975350499153137
# 290 2.9753427028656008
# 291 2.975342071056366
# 292 2.9753389090299605
# 293 2.9753347992897035
# 294 2.9753297865390778
# 295 2.9753271490335464
# 296 2.9753220587968827
# 297 2.975315174460411
# 298 2.975311142206192
# 299 2.9753109723329545
# 300 2.9753080368041993

# %%
plt.figure(figsize=(5, 5))
plt.plot(np.arange(len(losses_epoch)), losses_epoch, linewidth=1)
plt.ylim(2.8, 3.2)
plt.show()

# %%
with torch.no_grad():
    ms, vs = maf.get_ms_and_vs(data)
    probs = maf.log_prob(grid, ms=ms, vs=vs).exp()

plt.figure(figsize=(5, 5))

plt.contourf(
    xxs.numpy(), yys.numpy(), probs.numpy().reshape(100, 100),
    levels=100, cmap="turbo", extent=[-5, 9, -7.5, 7.5]
)

plt.xticks([])
plt.yticks([])

#plt.savefig(f"./saved/made_2d_density_estimation/{potential_func_name}_mog_c10_made.png", dpi=300, bbox_inches='tight')
plt.savefig(f"./saved/2d_density_estimation/{potential_func_name}_maf.png", dpi=300, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
#       1 with torch.no_grad():
# ----> 2     ms, vs = maf.get_ms_and_vs(data)
#       3     probs = maf.log_prob(grid, ms=ms, vs=vs).exp()
#       5 plt.figure(figsize=(5, 5))
#
# File ~/opt/miniconda3/envs/mlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'MADE_MOG' object has no attribute 'get_ms_and_vs'

# %%
with torch.no_grad():
    probs = maf.log_prob(grid).exp()

plt.figure(figsize=(5, 5))

plt.contourf(
    xxs.numpy(), yys.numpy(), probs.numpy().reshape(100, 100),
    levels=100, cmap="turbo", extent=[-5, 9, -7.5, 7.5]
)

plt.xticks([])
plt.yticks([])

#plt.savefig(f"./saved/made_2d_density_estimation/{potential_func_name}_mog_c10_made.png", dpi=300, bbox_inches='tight')
# plt.savefig(f"./saved/2d_density_estimation/{potential_func_name}_maf.png", dpi=300, bbox_inches="tight")
# Out:
# ([], [])

# %%
torch.exp(torch.Tensor([-10000.])) + 1e-4
# Out:
# tensor([1.0000e-04])
